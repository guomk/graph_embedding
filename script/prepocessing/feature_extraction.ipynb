# %%
from pathlib import Path
import pandas as pd
import numpy as np
from pprint import pprint

# %%
TARGET_FOLDER = Path('../../data/features/')

# %% [markdown]
# **One-hot vector as node feature**
# 1. read edgelist file
# 2. extract all nodes
# 3. one-hot encode all nodes
# 4. return df with two column [node, onehot]

# %%
FILE_NAME = 'gm_ppi_common_renamed.csv'
DATA_FOLDER = Path('../../data/')

# 1. Read edgelist
df = pd.read_csv(DATA_FOLDER / FILE_NAME)
df.shape
# Out:
# (44272, 6)

# %%
# 2. Extract all nodes
nodes = set(df['source']).union(set(df['target']))
nodes = list(nodes)
nodes.sort()
node_df = pd.DataFrame(nodes)

# %%
# Create one-hot encoding df
onehot_df = pd.get_dummies(node_df, prefix='node')

# Convert to np array and check whether it's diagnal matrix
# onehot = onehot_df.to_numpy()
# if np.count_nonzero(onehot - np.diag(np.diagonal(onehot))) == 0:
#     print("It's a diagnal matrix")

onehot_df.index = nodes
onehot_df
# Out:
#            node_@UBC_gm  node_A1CF_gm  node_A2M_gm  node_AAAS_gm  \
# @UBC_gm               1             0            0             0
# A1CF_gm               0             1            0             0
# A2M_gm                0             0            1             0
# AAAS_gm               0             0            0             1
# AACS_gm               0             0            0             0
# ...                 ...           ...          ...           ...
# ZYG11A_gm             0             0            0             0
# ZYG11B_gm             0             0            0             0
# ZYX_gm                0             0            0             0
# ZZEF1_gm              0             0            0             0
# eIF2A_gm              0             0            0             0
#
#            node_AACS_gm  node_AAGAB_gm  node_AAMP_gm  node_AARS2_gm  \
# @UBC_gm               0              0             0              0
# A1CF_gm               0              0             0              0
# A2M_gm                0              0             0              0
# AAAS_gm               0              0             0              0
# AACS_gm               1              0             0              0
# ...                 ...            ...           ...            ...
# ZYG11A_gm             0              0             0              0
# ZYG11B_gm             0              0             0              0
# ZYX_gm                0              0             0              0
# ZZEF1_gm              0              0             0              0
# eIF2A_gm              0              0             0              0
#
#            node_AARSD1_gm  node_AARS_gm  ...  node_ZSCAN21_gm  node_ZUFSP_gm  \
# @UBC_gm                 0             0  ...                0              0
# A1CF_gm                 0             0  ...                0              0
# A2M_gm                  0             0  ...                0              0
# AAAS_gm                 0             0  ...                0              0
# AACS_gm                 0             0  ...                0              0
# ...                   ...           ...  ...              ...            ...
# ZYG11A_gm               0             0  ...                0              0
# ZYG11B_gm               0             0  ...                0              0
# ZYX_gm                  0             0  ...                0              0
# ZZEF1_gm                0             0  ...                0              0
# eIF2A_gm                0             0  ...                0              0
#
#            node_ZW10_gm  node_ZWILCH_gm  node_ZWINT_gm  node_ZYG11A_gm  \
# @UBC_gm               0               0              0               0
# A1CF_gm               0               0              0               0
# A2M_gm                0               0              0               0
# AAAS_gm               0               0              0               0
# AACS_gm               0               0              0               0
# ...                 ...             ...            ...             ...
# ZYG11A_gm             0               0              0               1
# ZYG11B_gm             0               0              0               0
# ZYX_gm                0               0              0               0
# ZZEF1_gm              0               0              0               0
# eIF2A_gm              0               0              0               0
#
#            node_ZYG11B_gm  node_ZYX_gm  node_ZZEF1_gm  node_eIF2A_gm
# @UBC_gm                 0            0              0              0
# A1CF_gm                 0            0              0              0
# A2M_gm                  0            0              0              0
# AAAS_gm                 0            0              0              0
# AACS_gm                 0            0              0              0
# ...                   ...          ...            ...            ...
# ZYG11A_gm               0            0              0              0
# ZYG11B_gm               1            0              0              0
# ZYX_gm                  0            1              0              0
# ZZEF1_gm                0            0              1              0
# eIF2A_gm                0            0              0              1
#
# [8760 rows x 8760 columns]

# %%
onehot_df.to_csv(TARGET_FOLDER / f'{FILE_NAME[:-4]}_onehot_names.csv', index=True)

# %% [markdown]
# ****
